# %% [markdown]
# # Clickstream Project
#
# Your client `Kirana Store` is an E-commerce company. The company wants to focus on targeting the right customers  with the right products to increase overall revenue and conversion rate.
#
# `Kirana Store` has provided you with the clickstream data on their website and wants you to tell them the answer to their queries. This will help them improve their understanding about their customers so that they can create better product personalization, marketing campaigns, advertisements, etc.
#
# The data contains the following fields :-
#
# - `webClientID` - Unique ID of browser for every system. (If a visitor is using multiple browsers on a system like Chrome, Safari, then there would be a different web clientid for each browser).
#
# - `VisitDateTime` - Date and time of visit.
#
# - `ProductID` - Unique ID of product browsed/ clicked by the visitor.
#
# - `Activity` - Type of activity can be browsing (`pageload`) or clicking (`click`) a product
#
# - `device` - Information about the device used by visitor to visit the website
# > - `Browser` - Browser used by visitor
# > - `OS` - OS used by the visitor
#
# - `user` - Information about registered user or users who have already signed up
# > - `UserID` - Unique ID of the user
# > - `City` - City of the user
# > - `Country` - Country of the user

# %% [markdown]
# ----
# ## Connecting to MongoDB
#
# ----

# %%
# Importing the required libraries
import pymongo
import pandas as pd
from datetime import datetime
import pprint as pp

# Does not allow pprint to sort the fields
pp.sorted = lambda x, key=None: x

# %%
# Connect to local MongoDB server
client = pymongo.MongoClient("mongodb+srv://vikasmandal380:Vikas995511@cluster0.ngqbv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# %%
# # Restore database
# !mongorestore /home/avadmin/Desktop/Mongo/Content/Project/Project_data/project

# %%
# Choose the database
db = client['Clickstream']
collection = db["project"]

# %%
import os 
import bson
os.chdir(r"C:\Users\vicky\Downloads\Project-210706-173732\Project\Project_data\Project_data\project\project")

# %%
os.listdir()
# Out:
# ['clicks.bson', 'clicks.metadata.json', 'clicks.zip']

# %%
with open('clicks.bson', "rb") as bson_file:
    for doc in bson.decode_file_iter(bson_file):
        collection.update_one({'_id': doc['_id']}, {'$set': doc}, upsert=True)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[7], line 3
#       1 with open('clicks.bson', "rb") as bson_file:
#       2     for doc in bson.decode_file_iter(bson_file):
# ----> 3         collection.update_one({'_id': doc['_id']}, {'$set': doc}, upsert=True)
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1336, in Collection.update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session, let, sort, comment)
#    1332 common.validate_list_or_none("array_filters", array_filters)
#    1334 write_concern = self._write_concern_for(session)
#    1335 return UpdateResult(
# -> 1336     self._update_retryable(
#    1337         filter,
#    1338         update,
#    1339         _Op.UPDATE,
#    1340         upsert,
#    1341         write_concern=write_concern,
#    1342         bypass_doc_val=bypass_document_validation,
#    1343         collation=collation,
#    1344         array_filters=array_filters,
#    1345         hint=hint,
#    1346         session=session,
#    1347         let=let,
#    1348         sort=sort,
#    1349         comment=comment,
#    1350     ),
#    1351     write_concern.acknowledged,
#    1352 )
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1118, in Collection._update_retryable(self, criteria, document, operation, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, sort, comment)
#    1095 def _update(
#    1096     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1097 ) -> Optional[Mapping[str, Any]]:
#    1098     return self._update(
#    1099         conn,
#    1100         criteria,
#    (...)
#    1115         comment=comment,
#    1116     )
# -> 1118 return self._database.client._retryable_write(
#    1119     (write_concern or self.write_concern).acknowledged and not multi,
#    1120     _update,
#    1121     session,
#    1122     operation,
#    1123 )
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1896, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1882 """Execute an operation with consecutive retries if possible
#    1883
#    1884 Returns func()'s return value on success. On error retries the same
#    (...)
#    1893 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1894 """
#    1895 with self._tmp_session(session) as s:
# -> 1896     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1782, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1777 # Ensure that the options supports retry_writes and there is a valid session not in
#    1778 # transaction, otherwise, we will not support retry behavior for this txn.
#    1779 retryable = bool(
#    1780     retryable and self.options.retry_writes and session and not session.in_transaction
#    1781 )
# -> 1782 return self._retry_internal(
#    1783     func=func,
#    1784     session=session,
#    1785     bulk=bulk,
#    1786     operation=operation,
#    1787     retryable=retryable,
#    1788     operation_id=operation_id,
#    1789 )
#
# File ~\anaconda3\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:1828, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1791 @_csot.apply
#    1792 def _retry_internal(
#    1793     self,
#    (...)
#    1802     operation_id: Optional[int] = None,
#    1803 ) -> T:
#    1804     """Internal retryable helper for all client transactions.
#    1805
#    1806     :param func: Callback function we want to retry
#    (...)
#    1815     :return: Output of the calling func()
#    1816     """
#    1817     return _ClientConnectionRetryable(
#    1818         mongo_client=self,
#    1819         func=func,
#    1820         bulk=bulk,
#    1821         operation=operation,
#    1822         is_read=is_read,
#    1823         session=session,
#    1824         read_pref=read_pref,
#    1825         address=address,
#    1826         retryable=retryable,
#    1827         operation_id=operation_id,
# -> 1828     ).run()
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2565, in _ClientConnectionRetryable.run(self)
#    2563 self._check_last_error(check_csot=True)
#    2564 try:
# -> 2565     return self._read() if self._is_read else self._write()
#    2566 except ServerSelectionTimeoutError:
#    2567     # The application may think the write was never attempted
#    2568     # if we raise ServerSelectionTimeoutError on the retry
#    2569     # attempt. Raise the original exception instead.
#    2570     self._check_last_error()
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\mongo_client.py:2687, in _ClientConnectionRetryable._write(self)
#    2685             self._check_last_error()
#    2686             self._retryable = False
# -> 2687         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2688 except PyMongoError as exc:
#    2689     if not self._retryable:
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1098, in Collection._update_retryable.<locals>._update(session, conn, retryable_write)
#    1095 def _update(
#    1096     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#    1097 ) -> Optional[Mapping[str, Any]]:
# -> 1098     return self._update(
#    1099         conn,
#    1100         criteria,
#    1101         document,
#    1102         upsert=upsert,
#    1103         multi=multi,
#    1104         write_concern=write_concern,
#    1105         op_id=op_id,
#    1106         ordered=ordered,
#    1107         bypass_doc_val=bypass_doc_val,
#    1108         collation=collation,
#    1109         array_filters=array_filters,
#    1110         hint=hint,
#    1111         session=session,
#    1112         retryable_write=retryable_write,
#    1113         let=let,
#    1114         sort=sort,
#    1115         comment=comment,
#    1116     )
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\collection.py:1049, in Collection._update(self, conn, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write, let, sort, comment)
#    1044     command["bypassDocumentValidation"] = True
#    1046 # The command result has to be published for APM unmodified
#    1047 # so we make a shallow copy here before adding updatedExisting.
#    1048 result = (
# -> 1049     conn.command(
#    1050         self._database.name,
#    1051         command,
#    1052         write_concern=write_concern,
#    1053         codec_options=self._write_response_codec_options,
#    1054         session=session,
#    1055         client=self._database.client,
#    1056         retryable_write=retryable_write,
#    1057     )
#    1058 ).copy()
#    1059 _check_write_command_response(result)
#    1060 # Add the updatedExisting field for compatibility.
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\pool.py:536, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     534     self._raise_if_not_writable(unacknowledged)
#     535 try:
# --> 536     return command(
#     537         self,
#     538         dbname,
#     539         spec,
#     540         self.is_mongos,
#     541         read_preference,
#     542         codec_options,
#     543         session,
#     544         client,
#     545         check,
#     546         allowable_errors,
#     547         self.address,
#     548         listeners,
#     549         self.max_bson_size,
#     550         read_concern,
#     551         parse_write_concern_error=parse_write_concern_error,
#     552         collation=collation,
#     553         compression_ctx=self.compression_context,
#     554         use_op_msg=self.op_msg_enabled,
#     555         unacknowledged=unacknowledged,
#     556         user_fields=user_fields,
#     557         exhaust_allowed=exhaust_allowed,
#     558         write_concern=write_concern,
#     559     )
#     560 except (OperationFailure, NotPrimaryError):
#     561     raise
#
# File ~\anaconda3\Lib\site-packages\pymongo\synchronous\network.py:213, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     211             client._process_response(response_doc, session)
#     212         if check:
# --> 213             helpers_shared._check_command_response(
#     214                 response_doc,
#     215                 conn.max_wire_version,
#     216                 allowable_errors,
#     217                 parse_write_concern_error=parse_write_concern_error,
#     218             )
#     219 except Exception as exc:
#     220     duration = datetime.datetime.now() - start
#
# File ~\anaconda3\Lib\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: you are over your space quota, using 512 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 512 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}

# %%
# Sample document
pp.pprint(
    db.clicks.find_one()
)
# Out:
# None

# %% [markdown]
# ---
# ## Overiew of the data
#
# ----

# %% [markdown]
# Number of documents in the collection

# %%
db.clicks.find().count()
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 6100000

# %% [markdown]
# ---
# Minimum date for which the records are present

# %%
cur = db.clicks.find({}, {'VisitDateTime': 1, '_id': 0})\
               .sort([('VisitDateTime', pymongo.ASCENDING)])\
               .limit(1)

for doc in cur:
    pp.pprint(doc)
# Out:
# {'VisitDateTime': datetime.datetime(2018, 5, 7, 0, 0, 1, 190000)}

# %% [markdown]
# ----
# Maximum date  for which the records are present

# %%
cur = db.clicks.find({}, {'VisitDateTime': 1, '_id': 0})\
               .sort([('VisitDateTime', pymongo.DESCENDING)])\
               .limit(1)

for doc in cur:
    pp.pprint(doc)
# Out:
# {'VisitDateTime': datetime.datetime(2018, 5, 27, 23, 59, 59, 576000)}

# %% [markdown]
# ----
# Number of documents that have `user.UserID` field or number of users who have signed up on the website.

# %%
db.clicks.find({'user.UserID': {'$exists': True}}).count()
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 602293

# %% [markdown]
# ---
# Unique signed up users in the complete data

# %%
len(db.clicks.find({'user.UserID': {'$exists': True}}).distinct('user.UserID'))
# Out:
# 34050

# %% [markdown]
# ---
# Unique countries and cities

# %%
cur = db.clicks.aggregate([
            {
                '$match': {
                            'user.Country': {'$exists':True},
                            'user.City': {'$exists': True}
                        }
            },
            {
                '$group': {
                                '_id': {
                                            'Country': '$user.Country', 
                                            'City': '$user.City'
                                        }
                        }
            },
            {
                '$sort': {'_id.Country': 1}
            }
        ])

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': {'Country': 'Afghanistan', 'City': 'Kabul'}}
# {'_id': {'Country': 'Albania', 'City': 'Lezhë'}}
# {'_id': {'Country': 'Albania', 'City': 'Elbasan'}}
# {'_id': {'Country': 'Albania', 'City': 'Shkoder'}}
# {'_id': {'Country': 'Albania', 'City': 'Kosove'}}
# {'_id': {'Country': 'Albania', 'City': 'Korçë'}}
# {'_id': {'Country': 'Albania', 'City': 'Tirana'}}
# {'_id': {'Country': 'Albania', 'City': 'Durrës'}}
# {'_id': {'Country': 'Albania', 'City': 'Yzberish'}}
# {'_id': {'Country': 'Albania', 'City': 'Fier'}}
# {'_id': {'Country': 'Algeria', 'City': 'Khemis Miliana'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Biar'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Kercha'}}
# {'_id': {'Country': 'Algeria', 'City': 'Draa el Mizan'}}
# {'_id': {'Country': 'Algeria', 'City': 'Khemis el Khechna'}}
# {'_id': {'Country': 'Algeria', 'City': 'Gouraya'}}
# {'_id': {'Country': 'Algeria', 'City': 'Miliana'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ras el Oued'}}
# {'_id': {'Country': 'Algeria', 'City': 'Saida'}}
# {'_id': {'Country': 'Algeria', 'City': 'Constantine'}}
# {'_id': {'Country': 'Algeria', 'City': 'Laghouat'}}
# {'_id': {'Country': 'Algeria', 'City': 'Douéra'}}
# {'_id': {'Country': 'Algeria', 'City': 'Makouda'}}
# {'_id': {'Country': 'Algeria', 'City': 'Dar el Beida'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bab Ezzouar'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bougaa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hammamet'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oran'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oum el Bouaghi'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Beida'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Fakroun'}}
# {'_id': {'Country': 'Algeria', 'City': 'Beni Abbes'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oued el Abtal'}}
# {'_id': {'Country': 'Algeria', 'City': "'Ain el Melh"}}
# {'_id': {'Country': 'Algeria', 'City': 'Aokas'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tébessa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tizi Ouzou'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Affroun'}}
# {'_id': {'Country': 'Algeria', 'City': 'Dellys'}}
# {'_id': {'Country': 'Algeria', 'City': 'Barika'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bir el Ater'}}
# {'_id': {'Country': 'Algeria', 'City': "M'Sila"}}
# {'_id': {'Country': 'Algeria', 'City': 'Teniet el Abed'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Harrach'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boudouaou'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bir el Djir'}}
# {'_id': {'Country': 'Algeria', 'City': 'Commune de Draa Ben Khedda'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tin Alkoum'}}
# {'_id': {'Country': 'Algeria', 'City': 'Relizane'}}
# {'_id': {'Country': 'Algeria', 'City': 'Nedroma'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Amrane'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oued el Alleug'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tiaret'}}
# {'_id': {'Country': 'Algeria', 'City': 'Beni Guecha'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bou Arfa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mers el Kebir'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tighenif'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boghni'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tlemcen'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Eulma'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ksar Chellala'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ksar el Boukhari'}}
# {'_id': {'Country': 'Algeria', 'City': 'Amizour'}}
# {'_id': {'Country': 'Algeria', 'City': 'Baraki'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Bel Abbes'}}
# {'_id': {'Country': 'Algeria', 'City': 'Rouissat'}}
# {'_id': {'Country': 'Algeria', 'City': 'Souk Ahras'}}
# {'_id': {'Country': 'Algeria', 'City': 'Fouka'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tizi-n-Tleta'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ouargla'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ighram'}}
# {'_id': {'Country': 'Algeria', 'City': 'Messaad'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bensekrane'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mila'}}
# {'_id': {'Country': 'Algeria', 'City': 'Zeribet el Oued'}}
# {'_id': {'Country': 'Algeria', 'City': 'Béjaïa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Souahlia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oued Fodda'}}
# {'_id': {'Country': 'Algeria', 'City': 'Oued Smar'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hussein Dey'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj Bou Arreridj'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Hadjira'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hennaya'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boudjima'}}
# {'_id': {'Country': 'Algeria', 'City': 'Kouba'}}
# {'_id': {'Country': 'Algeria', 'City': 'Rouiba'}}
# {'_id': {'Country': 'Algeria', 'City': 'Medea'}}
# {'_id': {'Country': 'Algeria', 'City': 'Adrar'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sougueur'}}
# {'_id': {'Country': 'Algeria', 'City': 'Djelfa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sfizef'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bourouba'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Touta'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boukhralfa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Azelouaz'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tadmait'}}
# {'_id': {'Country': 'Algeria', 'City': 'Khemis'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj Ghdir'}}
# {'_id': {'Country': 'Algeria', 'City': 'Béchar'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Aissa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Khenchela'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Temouchent'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sig'}}
# {'_id': {'Country': 'Algeria', 'City': 'Biskra'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain el Hadjel'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hassi Bel Guebbour'}}
# {'_id': {'Country': 'Algeria', 'City': 'Guelma'}}
# {'_id': {'Country': 'Algeria', 'City': 'Saoula'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mascara'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hamma Bouziane'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Ghiles'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tolga'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tizi Gheniff'}}
# {'_id': {'Country': 'Algeria', 'City': 'Khalouia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Meftah'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tidjelabine'}}
# {'_id': {'Country': 'Algeria', 'City': 'Frenda'}}
# {'_id': {'Country': 'Algeria', 'City': 'Algiers'}}
# {'_id': {'Country': 'Algeria', 'City': 'Zemoura'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mostaganem'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj Zemoura'}}
# {'_id': {'Country': 'Algeria', 'City': 'Cheraga'}}
# {'_id': {'Country': 'Algeria', 'City': 'Souma'}}
# {'_id': {'Country': 'Algeria', 'City': 'Jijel'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Bayadh'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ras el Aioun'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj el Bahri'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ouenza'}}
# {'_id': {'Country': 'Algeria', 'City': 'Naama'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj Omar Driss'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ouled Djellal'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Amria'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Kebir'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mekla'}}
# {'_id': {'Country': 'Algeria', 'City': 'Chorfa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Aflou'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Khroub'}}
# {'_id': {'Country': 'Algeria', 'City': "L'Arbaa Nait Irathen"}}
# {'_id': {'Country': 'Algeria', 'City': 'Annaba'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sétif'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Milia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Abou el Hassan'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Oussera'}}
# {'_id': {'Country': 'Algeria', 'City': 'Texenna'}}
# {'_id': {'Country': 'Algeria', 'City': 'Hadjout'}}
# {'_id': {'Country': 'Algeria', 'City': 'Akbou'}}
# {'_id': {'Country': 'Algeria', 'City': 'Reghaia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Remchi'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mocta Douz'}}
# {'_id': {'Country': 'Algeria', 'City': 'Theniet el Had'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sidi Akkacha'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boufarik'}}
# {'_id': {'Country': 'Algeria', 'City': 'Reggane'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj el Kiffan'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mansourah'}}
# {'_id': {'Country': 'Algeria', 'City': 'Zeralda'}}
# {'_id': {'Country': 'Algeria', 'City': "'Ain Benian"}}
# {'_id': {'Country': 'Algeria', 'City': 'Khemisti'}}
# {'_id': {'Country': 'Algeria', 'City': 'Birkhadem'}}
# {'_id': {'Country': 'Algeria', 'City': 'Aïn Arnat'}}
# {'_id': {'Country': 'Algeria', 'City': 'Es Senia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Batna City'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Sefra'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Omaria'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tamanghasset'}}
# {'_id': {'Country': 'Algeria', 'City': 'Sedrata'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tipasa'}}
# {'_id': {'Country': 'Algeria', 'City': 'Melouza'}}
# {'_id': {'Country': 'Algeria', 'City': 'Chlef'}}
# {'_id': {'Country': 'Algeria', 'City': 'Youb'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bouïra'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bouhmama'}}
# {'_id': {'Country': 'Algeria', 'City': 'Arris'}}
# {'_id': {'Country': 'Algeria', 'City': 'Tamadjert'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bouchegouf'}}
# {'_id': {'Country': 'Algeria', 'City': 'Blida'}}
# {'_id': {'Country': 'Algeria', 'City': 'Boukadir'}}
# {'_id': {'Country': 'Algeria', 'City': 'Baghlia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Azazga'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Idrissia'}}
# {'_id': {'Country': 'Algeria', 'City': 'Djanet'}}
# {'_id': {'Country': 'Algeria', 'City': 'El Tarf'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mehdia daira de meghila'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bougara'}}
# {'_id': {'Country': 'Algeria', 'City': 'Skikda'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mazouna'}}
# {'_id': {'Country': 'Algeria', 'City': 'Bordj de Chegga'}}
# {'_id': {'Country': 'Algeria', 'City': 'Mamoura'}}
# {'_id': {'Country': 'Algeria', 'City': 'Ain Defla'}}
# {'_id': {'Country': 'Andorra', 'City': 'Canillo'}}
# {'_id': {'Country': 'Andorra', 'City': 'Andorra la Vella'}}
# {'_id': {'Country': 'Andorra', 'City': 'Encamp'}}
# {'_id': {'Country': 'Andorra', 'City': 'La Massana'}}
# {'_id': {'Country': 'Angola', 'City': 'Camabatela'}}
# {'_id': {'Country': 'Angola', 'City': 'Talatona'}}
# {'_id': {'Country': 'Angola', 'City': 'Luanda'}}
# {'_id': {'Country': 'Antigua and Barbuda', 'City': 'Piggotts'}}
# {'_id': {'Country': 'Antigua and Barbuda', 'City': "St John's"}}
# {'_id': {'Country': 'Argentina', 'City': 'Las Heras'}}
# {'_id': {'Country': 'Argentina', 'City': 'Piquillin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Dominico'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lomas de Zamora'}}
# {'_id': {'Country': 'Argentina', 'City': 'Concepción del Uruguay'}}
# {'_id': {'Country': 'Argentina', 'City': 'Glew'}}
# {'_id': {'Country': 'Argentina', 'City': 'Guernica'}}
# {'_id': {'Country': 'Argentina', 'City': 'Santo Tome'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Martín de los Andes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Canuelas'}}
# {'_id': {'Country': 'Argentina', 'City': 'Huanguelen'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cipolletti'}}
# {'_id': {'Country': 'Argentina', 'City': 'Vedia'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Guillermo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Allen'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tigre'}}
# {'_id': {'Country': 'Argentina', 'City': 'Munro'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lujan de Cuyo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Junín'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Andres'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Vicente'}}
# {'_id': {'Country': 'Argentina', 'City': 'Hurlingham'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rio Grande'}}
# {'_id': {'Country': 'Argentina', 'City': 'Alta Gracia'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Nicolás de los Arroyos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Chamical'}}
# {'_id': {'Country': 'Argentina', 'City': 'Jose Leon Suarez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Saladillo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Río Cuarto'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Antonio de Areco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Marcos Juarez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Santa Rosa'}}
# {'_id': {'Country': 'Argentina', 'City': 'Las Higueras'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Antonio de Padua'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Jose de San Martin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Posadas'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tio Pujio'}}
# {'_id': {'Country': 'Argentina', 'City': 'Caseros'}}
# {'_id': {'Country': 'Argentina', 'City': 'Godoy Cruz'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Villegas'}}
# {'_id': {'Country': 'Argentina', 'City': 'Yerba Buena'}}
# {'_id': {'Country': 'Argentina', 'City': 'Junin de los Andes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tafi Viejo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Madero'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Mercedes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Caballito'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tablada'}}
# {'_id': {'Country': 'Argentina', 'City': 'Don Torcuato'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Constitucion'}}
# {'_id': {'Country': 'Argentina', 'City': 'Olavarría'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Martin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Nueve de Julio'}}
# {'_id': {'Country': 'Argentina', 'City': 'Belen de Escobar'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Rosa'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bariloche'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cutral-Co'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bernal'}}
# {'_id': {'Country': 'Argentina', 'City': 'Neuquén'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Rumipal'}}
# {'_id': {'Country': 'Argentina', 'City': 'Santiago del Estero'}}
# {'_id': {'Country': 'Argentina', 'City': 'Santos Lugares'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa del Rosario'}}
# {'_id': {'Country': 'Argentina', 'City': 'Wilde'}}
# {'_id': {'Country': 'Argentina', 'City': 'Las Perdices'}}
# {'_id': {'Country': 'Argentina', 'City': 'Remedios de Escalada'}}
# {'_id': {'Country': 'Argentina', 'City': 'Paso del Rey'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cerrillos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rafael Castillo'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Justo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ciudadela'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Pico'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bella Vista'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Jose de la Dormida'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Rafael'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Adelina'}}
# {'_id': {'Country': 'Argentina', 'City': 'Quilmes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lanus'}}
# {'_id': {'Country': 'Argentina', 'City': 'Florencio Varela'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ensenada'}}
# {'_id': {'Country': 'Argentina', 'City': 'Venado Tuerto'}}
# {'_id': {'Country': 'Argentina', 'City': 'Buenos Aires'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa del Parque'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ushuaia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Funes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Colon'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rio Segundo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lomas del Mirador'}}
# {'_id': {'Country': 'Argentina', 'City': 'Beccar'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Miguel'}}
# {'_id': {'Country': 'Argentina', 'City': 'Maipu'}}
# {'_id': {'Country': 'Argentina', 'City': 'Arrecifes'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Francisco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Adrogue'}}
# {'_id': {'Country': 'Argentina', 'City': 'Azul'}}
# {'_id': {'Country': 'Argentina', 'City': 'Gomez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Aaron Castellanos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tortuguitas'}}
# {'_id': {'Country': 'Argentina', 'City': 'Belgrano'}}
# {'_id': {'Country': 'Argentina', 'City': 'Palpala'}}
# {'_id': {'Country': 'Argentina', 'City': 'Gerli'}}
# {'_id': {'Country': 'Argentina', 'City': 'Junin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rawson'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rio Ceballos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Luján'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Antonio Oeste'}}
# {'_id': {'Country': 'Argentina', 'City': 'Campana'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Las Heras'}}
# {'_id': {'Country': 'Argentina', 'City': 'Comodoro Rivadavia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Marcos Paz'}}
# {'_id': {'Country': 'Argentina', 'City': 'Chacabuco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Martinez'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Pedro'}}
# {'_id': {'Country': 'Argentina', 'City': 'Pergamino'}}
# {'_id': {'Country': 'Argentina', 'City': 'Centenario'}}
# {'_id': {'Country': 'Argentina', 'City': 'General La Madrid'}}
# {'_id': {'Country': 'Argentina', 'City': 'Morteros'}}
# {'_id': {'Country': 'Argentina', 'City': 'Balcarce'}}
# {'_id': {'Country': 'Argentina', 'City': 'Coronel Pringles'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cruz del Eje'}}
# {'_id': {'Country': 'Argentina', 'City': 'Sauce de Luna'}}
# {'_id': {'Country': 'Argentina', 'City': 'Candelaria'}}
# {'_id': {'Country': 'Argentina', 'City': 'Puerto San Martin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ituzaingo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Frontera'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Carlos Paz'}}
# {'_id': {'Country': 'Argentina', 'City': 'Mercedes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Esperanza'}}
# {'_id': {'Country': 'Argentina', 'City': 'Formosa'}}
# {'_id': {'Country': 'Argentina', 'City': 'Concepcion'}}
# {'_id': {'Country': 'Argentina', 'City': 'Salta'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Viamonte'}}
# {'_id': {'Country': 'Argentina', 'City': 'El Talar'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Pacheco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rafaela'}}
# {'_id': {'Country': 'Argentina', 'City': 'Garin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Boca de la Zanja'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cerrito'}}
# {'_id': {'Country': 'Argentina', 'City': 'Saenz Pena'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa María'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Giardino'}}
# {'_id': {'Country': 'Argentina', 'City': 'Acassuso'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Ramirez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Magdalena'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rafael Calzada'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rosario'}}
# {'_id': {'Country': 'Argentina', 'City': 'Corrientes'}}
# {'_id': {'Country': 'Argentina', 'City': 'Berisso'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Francisco Solano'}}
# {'_id': {'Country': 'Argentina', 'City': 'Serrano'}}
# {'_id': {'Country': 'Argentina', 'City': 'Castelar'}}
# {'_id': {'Country': 'Argentina', 'City': 'La Punta'}}
# {'_id': {'Country': 'Argentina', 'City': 'Alvear'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Lorenzo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Totoras'}}
# {'_id': {'Country': 'Argentina', 'City': 'Córdoba'}}
# {'_id': {'Country': 'Argentina', 'City': 'Burzaco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Anillaco'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ramos Mejia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Deseado'}}
# {'_id': {'Country': 'Argentina', 'City': 'Ingeniero Luiggi'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Deheza'}}
# {'_id': {'Country': 'Argentina', 'City': 'Del Viso'}}
# {'_id': {'Country': 'Argentina', 'City': 'General Roca'}}
# {'_id': {'Country': 'Argentina', 'City': 'Vicente Lopez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Longchamps'}}
# {'_id': {'Country': 'Argentina', 'City': 'Granadero Baigorria'}}
# {'_id': {'Country': 'Argentina', 'City': 'Veronica'}}
# {'_id': {'Country': 'Argentina', 'City': 'General San Martin'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Salvador de Jujuy'}}
# {'_id': {'Country': 'Argentina', 'City': 'Daireaux'}}
# {'_id': {'Country': 'Argentina', 'City': 'Rio Tercero'}}
# {'_id': {'Country': 'Argentina', 'City': 'Veinticinco de Mayo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Dock Sud'}}
# {'_id': {'Country': 'Argentina', 'City': 'Laboulaye'}}
# {'_id': {'Country': 'Argentina', 'City': 'Esteban Echeverria'}}
# {'_id': {'Country': 'Argentina', 'City': 'Temperley'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Miguel de Tucumán'}}
# {'_id': {'Country': 'Argentina', 'City': 'Flores'}}
# {'_id': {'Country': 'Argentina', 'City': 'Coronel Suárez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Mar del Plata'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lobos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Olivos'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Juan'}}
# {'_id': {'Country': 'Argentina', 'City': 'Obera'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bahía Blanca'}}
# {'_id': {'Country': 'Argentina', 'City': 'Victoria'}}
# {'_id': {'Country': 'Argentina', 'City': 'Goya'}}
# {'_id': {'Country': 'Argentina', 'City': 'Gualeguaychú'}}
# {'_id': {'Country': 'Argentina', 'City': 'Sarandi'}}
# {'_id': {'Country': 'Argentina', 'City': 'Sunchales'}}
# {'_id': {'Country': 'Argentina', 'City': 'Puerto Madryn'}}
# {'_id': {'Country': 'Argentina', 'City': 'Plottier'}}
# {'_id': {'Country': 'Argentina', 'City': 'Banfield'}}
# {'_id': {'Country': 'Argentina', 'City': 'Haedo'}}
# {'_id': {'Country': 'Argentina', 'City': 'Isidro Casanova'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cinco Saltos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Boulogne'}}
# {'_id': {'Country': 'Argentina', 'City': 'La Plata'}}
# {'_id': {'Country': 'Argentina', 'City': 'Zárate'}}
# {'_id': {'Country': 'Argentina', 'City': 'Constitucion'}}
# {'_id': {'Country': 'Argentina', 'City': 'La Rioja'}}
# {'_id': {'Country': 'Argentina', 'City': 'Presidente Derqui'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bragado'}}
# {'_id': {'Country': 'Argentina', 'City': 'Chilecito'}}
# {'_id': {'Country': 'Argentina', 'City': 'City Bell'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Allende'}}
# {'_id': {'Country': 'Argentina', 'City': 'Mariano Moreno'}}
# {'_id': {'Country': 'Argentina', 'City': 'Adelia Maria'}}
# {'_id': {'Country': 'Argentina', 'City': 'Moron'}}
# {'_id': {'Country': 'Argentina', 'City': 'Presidencia Roque Sáenz Peña'}}
# {'_id': {'Country': 'Argentina', 'City': 'Carlos Spegazzini'}}
# {'_id': {'Country': 'Argentina', 'City': 'Mendoza'}}
# {'_id': {'Country': 'Argentina', 'City': 'Puerto Iguazú'}}
# {'_id': {'Country': 'Argentina', 'City': 'Leandro N. Alem'}}
# {'_id': {'Country': 'Argentina', 'City': 'Capitan Sarmiento'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Nueva'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tres Arroyos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Pilar'}}
# {'_id': {'Country': 'Argentina', 'City': 'Laguna Alsina'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Fernando'}}
# {'_id': {'Country': 'Argentina', 'City': 'Dique Lujan'}}
# {'_id': {'Country': 'Argentina', 'City': 'Santa Fe'}}
# {'_id': {'Country': 'Argentina', 'City': 'Cosquin'}}
# {'_id': {'Country': 'Argentina', 'City': 'Corti'}}
# {'_id': {'Country': 'Argentina', 'City': 'Grand Bourg'}}
# {'_id': {'Country': 'Argentina', 'City': 'Lehmann'}}
# {'_id': {'Country': 'Argentina', 'City': 'Resistencia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Elisa'}}
# {'_id': {'Country': 'Argentina', 'City': 'Corral de Bustos'}}
# {'_id': {'Country': 'Argentina', 'City': 'Berazategui'}}
# {'_id': {'Country': 'Argentina', 'City': 'Merlo'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Isidro'}}
# {'_id': {'Country': 'Argentina', 'City': 'Andalgala'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tristan Suarez'}}
# {'_id': {'Country': 'Argentina', 'City': 'Paraná'}}
# {'_id': {'Country': 'Argentina', 'City': 'Chivilcoy'}}
# {'_id': {'Country': 'Argentina', 'City': 'Laferrere'}}
# {'_id': {'Country': 'Argentina', 'City': 'Florida'}}
# {'_id': {'Country': 'Argentina', 'City': 'Concordia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Manzanares'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tupungato'}}
# {'_id': {'Country': 'Argentina', 'City': 'Abbott'}}
# {'_id': {'Country': 'Argentina', 'City': 'Llavallol'}}
# {'_id': {'Country': 'Argentina', 'City': 'Villa Ballester'}}
# {'_id': {'Country': 'Argentina', 'City': 'Avellaneda'}}
# {'_id': {'Country': 'Argentina', 'City': 'Argentina'}}
# {'_id': {'Country': 'Argentina', 'City': 'Bell Ville'}}
# {'_id': {'Country': 'Argentina', 'City': 'Tandil'}}
# {'_id': {'Country': 'Argentina', 'City': 'San Luis'}}
# {'_id': {'Country': 'Argentina', 'City': 'Curuzu Cuatia'}}
# {'_id': {'Country': 'Argentina', 'City': 'Luis Guillon'}}
# {'_id': {'Country': 'Argentina', 'City': 'Canada de Gomez'}}
# {'_id': {'Country': 'Armenia', 'City': 'Vanadzor'}}
# {'_id': {'Country': 'Armenia', 'City': 'Yerevan'}}
# {'_id': {'Country': 'Armenia', 'City': 'Spitak'}}
# {'_id': {'Country': 'Armenia', 'City': 'Abovyan'}}
# {'_id': {'Country': 'Armenia', 'City': 'Gavarr'}}
# {'_id': {'Country': 'Armenia', 'City': 'Ijevan'}}
# {'_id': {'Country': 'Armenia', 'City': 'Gyumri'}}
# {'_id': {'Country': 'Aruba', 'City': 'Oranjestad'}}
# {'_id': {'Country': 'Aruba', 'City': 'Noord'}}
# {'_id': {'Country': 'Australia', 'City': 'Boyne Island'}}
# {'_id': {'Country': 'Australia', 'City': 'Cammeray'}}
# {'_id': {'Country': 'Australia', 'City': 'Abbotsford'}}
# {'_id': {'Country': 'Australia', 'City': 'Brisbane'}}
# {'_id': {'Country': 'Australia', 'City': 'Seaforth'}}
# {'_id': {'Country': 'Australia', 'City': 'Bonython'}}
# {'_id': {'Country': 'Australia', 'City': 'Kent Town'}}
# {'_id': {'Country': 'Australia', 'City': 'Wembley'}}
# {'_id': {'Country': 'Australia', 'City': 'Bohle Plains'}}
# {'_id': {'Country': 'Australia', 'City': 'Caversham'}}
# {'_id': {'Country': 'Australia', 'City': 'Pennant Hills'}}
# {'_id': {'Country': 'Australia', 'City': 'Little Hampton'}}
# {'_id': {'Country': 'Australia', 'City': 'Warwick'}}
# {'_id': {'Country': 'Australia', 'City': 'Clarinda'}}
# {'_id': {'Country': 'Australia', 'City': 'Northbridge'}}
# {'_id': {'Country': 'Australia', 'City': 'Willaston'}}
# {'_id': {'Country': 'Australia', 'City': 'Maroochydore'}}
# {'_id': {'Country': 'Australia', 'City': 'Bomaderry'}}
# {'_id': {'Country': 'Australia', 'City': 'Shortland'}}
# {'_id': {'Country': 'Australia', 'City': 'Cronulla'}}
# {'_id': {'Country': 'Australia', 'City': 'Northmead'}}
# {'_id': {'Country': 'Australia', 'City': 'Mango Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Sydenham'}}
# {'_id': {'Country': 'Australia', 'City': 'Newtown'}}
# {'_id': {'Country': 'Australia', 'City': 'The Basin'}}
# {'_id': {'Country': 'Australia', 'City': 'Hallam'}}
# {'_id': {'Country': 'Australia', 'City': 'New Town'}}
# {'_id': {'Country': 'Australia', 'City': 'Endeavour Hills'}}
# {'_id': {'Country': 'Australia', 'City': 'Eastwood'}}
# {'_id': {'Country': 'Australia', 'City': 'Auburn'}}
# {'_id': {'Country': 'Australia', 'City': 'Chatswood'}}
# {'_id': {'Country': 'Australia', 'City': 'Dianella'}}
# {'_id': {'Country': 'Australia', 'City': 'Broadford'}}
# {'_id': {'Country': 'Australia', 'City': 'Red Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Malvern'}}
# {'_id': {'Country': 'Australia', 'City': 'Campbell'}}
# {'_id': {'Country': 'Australia', 'City': 'Glenmore Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Westmead'}}
# {'_id': {'Country': 'Australia', 'City': 'Narrabeen'}}
# {'_id': {'Country': 'Australia', 'City': 'Gulgong'}}
# {'_id': {'Country': 'Australia', 'City': 'Australind'}}
# {'_id': {'Country': 'Australia', 'City': 'Surfers Paradise'}}
# {'_id': {'Country': 'Australia', 'City': 'Werribee'}}
# {'_id': {'Country': 'Australia', 'City': 'Brookvale'}}
# {'_id': {'Country': 'Australia', 'City': 'Bateau Bay'}}
# {'_id': {'Country': 'Australia', 'City': 'Leopold'}}
# {'_id': {'Country': 'Australia', 'City': 'Murchison'}}
# {'_id': {'Country': 'Australia', 'City': 'Diamond Creek'}}
# {'_id': {'Country': 'Australia', 'City': 'Kensington'}}
# {'_id': {'Country': 'Australia', 'City': 'Box Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Lakelands'}}
# {'_id': {'Country': 'Australia', 'City': 'Hawthorn'}}
# {'_id': {'Country': 'Australia', 'City': 'Blackburn'}}
# {'_id': {'Country': 'Australia', 'City': 'Regents Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Eltham North'}}
# {'_id': {'Country': 'Australia', 'City': 'Mayfield'}}
# {'_id': {'Country': 'Australia', 'City': 'Modbury'}}
# {'_id': {'Country': 'Australia', 'City': 'Roseworthy'}}
# {'_id': {'Country': 'Australia', 'City': 'Peakhurst'}}
# {'_id': {'Country': 'Australia', 'City': 'Chelsea'}}
# {'_id': {'Country': 'Australia', 'City': 'Turramurra'}}
# {'_id': {'Country': 'Australia', 'City': 'Oxenford'}}
# {'_id': {'Country': 'Australia', 'City': 'Tamworth'}}
# {'_id': {'Country': 'Australia', 'City': 'Engadine'}}
# {'_id': {'Country': 'Australia', 'City': 'Miranda'}}
# {'_id': {'Country': 'Australia', 'City': 'Berry'}}
# {'_id': {'Country': 'Australia', 'City': 'Avalon Beach'}}
# {'_id': {'Country': 'Australia', 'City': 'Tuggeranong Administrative District'}}
# {'_id': {'Country': 'Australia', 'City': 'Neutral Bay'}}
# {'_id': {'Country': 'Australia', 'City': 'Port Macquarie'}}
# {'_id': {'Country': 'Australia', 'City': 'Waikerie'}}
# {'_id': {'Country': 'Australia', 'City': 'Birkdale'}}
# {'_id': {'Country': 'Australia', 'City': 'Pomonal'}}
# {'_id': {'Country': 'Australia', 'City': 'Montrose'}}
# {'_id': {'Country': 'Australia', 'City': 'Stuart Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Templestowe'}}
# {'_id': {'Country': 'Australia', 'City': 'Wentworth Falls'}}
# {'_id': {'Country': 'Australia', 'City': 'Matraville'}}
# {'_id': {'Country': 'Australia', 'City': 'Schofields'}}
# {'_id': {'Country': 'Australia', 'City': 'Truganina'}}
# {'_id': {'Country': 'Australia', 'City': 'Toorak'}}
# {'_id': {'Country': 'Australia', 'City': 'Parkdale'}}
# {'_id': {'Country': 'Australia', 'City': 'Mount Cotton'}}
# {'_id': {'Country': 'Australia', 'City': 'Glen Iris'}}
# {'_id': {'Country': 'Australia', 'City': 'Chandler'}}
# {'_id': {'Country': 'Australia', 'City': 'Nuriootpa'}}
# {'_id': {'Country': 'Australia', 'City': 'Rosebery'}}
# {'_id': {'Country': 'Australia', 'City': 'Wyongah'}}
# {'_id': {'Country': 'Australia', 'City': 'Kew'}}
# {'_id': {'Country': 'Australia', 'City': 'Galston'}}
# {'_id': {'Country': 'Australia', 'City': 'Watsonia'}}
# {'_id': {'Country': 'Australia', 'City': 'Broken Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Bellevue Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Devonport'}}
# {'_id': {'Country': 'Australia', 'City': 'Mount Gambier'}}
# {'_id': {'Country': 'Australia', 'City': 'Belfield'}}
# {'_id': {'Country': 'Australia', 'City': 'North Lakes'}}
# {'_id': {'Country': 'Australia', 'City': 'Belair'}}
# {'_id': {'Country': 'Australia', 'City': 'Lyndhurst'}}
# {'_id': {'Country': 'Australia', 'City': 'Pakenham East'}}
# {'_id': {'Country': 'Australia', 'City': 'Edithvale'}}
# {'_id': {'Country': 'Australia', 'City': 'Islington'}}
# {'_id': {'Country': 'Australia', 'City': 'Padstow'}}
# {'_id': {'Country': 'Australia', 'City': 'Coorparoo'}}
# {'_id': {'Country': 'Australia', 'City': 'Forest Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Hobart'}}
# {'_id': {'Country': 'Australia', 'City': 'Terrigal'}}
# {'_id': {'Country': 'Australia', 'City': 'Beaumont'}}
# {'_id': {'Country': 'Australia', 'City': 'Riverwood'}}
# {'_id': {'Country': 'Australia', 'City': 'Garvoc'}}
# {'_id': {'Country': 'Australia', 'City': 'Gnangara'}}
# {'_id': {'Country': 'Australia', 'City': 'Secret Harbour'}}
# {'_id': {'Country': 'Australia', 'City': 'Melton South'}}
# {'_id': {'Country': 'Australia', 'City': 'Box Hill South'}}
# {'_id': {'Country': 'Australia', 'City': 'Sunshine'}}
# {'_id': {'Country': 'Australia', 'City': 'Belmont'}}
# {'_id': {'Country': 'Australia', 'City': 'Lyneham'}}
# {'_id': {'Country': 'Australia', 'City': 'Pendle Hills'}}
# {'_id': {'Country': 'Australia', 'City': 'Caringbah'}}
# {'_id': {'Country': 'Australia', 'City': 'Doonside'}}
# {'_id': {'Country': 'Australia', 'City': 'Condamine'}}
# {'_id': {'Country': 'Australia', 'City': 'Moorooka'}}
# {'_id': {'Country': 'Australia', 'City': 'Coogee'}}
# {'_id': {'Country': 'Australia', 'City': 'Browns Plains'}}
# {'_id': {'Country': 'Australia', 'City': 'New Lambton'}}
# {'_id': {'Country': 'Australia', 'City': 'Carnegie'}}
# {'_id': {'Country': 'Australia', 'City': 'Timboon'}}
# {'_id': {'Country': 'Australia', 'City': 'Essendon'}}
# {'_id': {'Country': 'Australia', 'City': 'Yarrawarrah'}}
# {'_id': {'Country': 'Australia', 'City': 'Charlestown'}}
# {'_id': {'Country': 'Australia', 'City': 'Bundoora'}}
# {'_id': {'Country': 'Australia', 'City': 'East Hills'}}
# {'_id': {'Country': 'Australia', 'City': 'Park Orchards'}}
# {'_id': {'Country': 'Australia', 'City': 'Darra'}}
# {'_id': {'Country': 'Australia', 'City': 'Eatons Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Glenorchy'}}
# {'_id': {'Country': 'Australia', 'City': 'Oakleigh South'}}
# {'_id': {'Country': 'Australia', 'City': 'Rozelle'}}
# {'_id': {'Country': 'Australia', 'City': 'Shepparton'}}
# {'_id': {'Country': 'Australia', 'City': 'Balaklava'}}
# {'_id': {'Country': 'Australia', 'City': 'Northcote'}}
# {'_id': {'Country': 'Australia', 'City': 'Forde'}}
# {'_id': {'Country': 'Australia', 'City': 'Campsie'}}
# {'_id': {'Country': 'Australia', 'City': 'Whyalla'}}
# {'_id': {'Country': 'Australia', 'City': 'Virginia'}}
# {'_id': {'Country': 'Australia', 'City': 'Greenacre'}}
# {'_id': {'Country': 'Australia', 'City': 'Clayton South'}}
# {'_id': {'Country': 'Australia', 'City': 'Clyde'}}
# {'_id': {'Country': 'Australia', 'City': 'Croydon'}}
# {'_id': {'Country': 'Australia', 'City': 'Surrey Hills'}}
# {'_id': {'Country': 'Australia', 'City': 'Rosanna'}}
# {'_id': {'Country': 'Australia', 'City': 'Ballarat'}}
# {'_id': {'Country': 'Australia', 'City': 'Bass Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Bairnsdale'}}
# {'_id': {'Country': 'Australia', 'City': 'Blackwall'}}
# {'_id': {'Country': 'Australia', 'City': 'Rockhampton'}}
# {'_id': {'Country': 'Australia', 'City': 'Ripley'}}
# {'_id': {'Country': 'Australia', 'City': 'Burwood East'}}
# {'_id': {'Country': 'Australia', 'City': 'Maribyrnong'}}
# {'_id': {'Country': 'Australia', 'City': 'Glen Huntly'}}
# {'_id': {'Country': 'Australia', 'City': 'City Beach'}}
# {'_id': {'Country': 'Australia', 'City': 'Kareela'}}
# {'_id': {'Country': 'Australia', 'City': 'Hoppers Crossing'}}
# {'_id': {'Country': 'Australia', 'City': 'Brighton-Le-Sands'}}
# {'_id': {'Country': 'Australia', 'City': 'Point Piper'}}
# {'_id': {'Country': 'Australia', 'City': 'Darwin'}}
# {'_id': {'Country': 'Australia', 'City': 'Heidelberg West'}}
# {'_id': {'Country': 'Australia', 'City': 'Scoresby'}}
# {'_id': {'Country': 'Australia', 'City': 'Caulfield South'}}
# {'_id': {'Country': 'Australia', 'City': 'Cherrybrook'}}
# {'_id': {'Country': 'Australia', 'City': 'Epping'}}
# {'_id': {'Country': 'Australia', 'City': 'Eight Mile Plains'}}
# {'_id': {'Country': 'Australia', 'City': 'Seaton'}}
# {'_id': {'Country': 'Australia', 'City': 'Tullamarine'}}
# {'_id': {'Country': 'Australia', 'City': 'Moolap'}}
# {'_id': {'Country': 'Australia', 'City': 'Bentleigh'}}
# {'_id': {'Country': 'Australia', 'City': 'Kelvin Grove'}}
# {'_id': {'Country': 'Australia', 'City': 'Robina'}}
# {'_id': {'Country': 'Australia', 'City': 'Coburg'}}
# {'_id': {'Country': 'Australia', 'City': 'Fairy Meadow'}}
# {'_id': {'Country': 'Australia', 'City': 'Mosman Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Thornlie'}}
# {'_id': {'Country': 'Australia', 'City': 'Woy Woy'}}
# {'_id': {'Country': 'Australia', 'City': 'Cottesloe'}}
# {'_id': {'Country': 'Australia', 'City': 'Fyansford'}}
# {'_id': {'Country': 'Australia', 'City': 'Yinnar'}}
# {'_id': {'Country': 'Australia', 'City': 'Canberra'}}
# {'_id': {'Country': 'Australia', 'City': 'Mandurah'}}
# {'_id': {'Country': 'Australia', 'City': 'Pymble'}}
# {'_id': {'Country': 'Australia', 'City': 'Crace'}}
# {'_id': {'Country': 'Australia', 'City': 'Carrington'}}
# {'_id': {'Country': 'Australia', 'City': 'Upper Mudgeeraba'}}
# {'_id': {'Country': 'Australia', 'City': 'Bondi'}}
# {'_id': {'Country': 'Australia', 'City': 'Bedford Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Karratha'}}
# {'_id': {'Country': 'Australia', 'City': 'Robertstown'}}
# {'_id': {'Country': 'Australia', 'City': 'Bittern'}}
# {'_id': {'Country': 'Australia', 'City': 'Gympie'}}
# {'_id': {'Country': 'Australia', 'City': 'Somerville'}}
# {'_id': {'Country': 'Australia', 'City': 'Wamberal North'}}
# {'_id': {'Country': 'Australia', 'City': 'Mitcham'}}
# {'_id': {'Country': 'Australia', 'City': 'Dover'}}
# {'_id': {'Country': 'Australia', 'City': 'Sandy Beach'}}
# {'_id': {'Country': 'Australia', 'City': 'Thornton'}}
# {'_id': {'Country': 'Australia', 'City': 'Monash'}}
# {'_id': {'Country': 'Australia', 'City': 'Deception Bay'}}
# {'_id': {'Country': 'Australia', 'City': 'Saint Ives'}}
# {'_id': {'Country': 'Australia', 'City': 'Kalgoorlie'}}
# {'_id': {'Country': 'Australia', 'City': 'Ashburton'}}
# {'_id': {'Country': 'Australia', 'City': 'Balwyn'}}
# {'_id': {'Country': 'Australia', 'City': 'Kurnell'}}
# {'_id': {'Country': 'Australia', 'City': 'Donvale'}}
# {'_id': {'Country': 'Australia', 'City': 'Redcliffe'}}
# {'_id': {'Country': 'Australia', 'City': 'Capalaba'}}
# {'_id': {'Country': 'Australia', 'City': 'Wagga Wagga'}}
# {'_id': {'Country': 'Australia', 'City': 'Stanthorpe'}}
# {'_id': {'Country': 'Australia', 'City': 'Annerley'}}
# {'_id': {'Country': 'Australia', 'City': 'Templestowe Lower'}}
# {'_id': {'Country': 'Australia', 'City': 'Jerrabomberra'}}
# {'_id': {'Country': 'Australia', 'City': 'Paddington'}}
# {'_id': {'Country': 'Australia', 'City': 'Avoca Beach'}}
# {'_id': {'Country': 'Australia', 'City': 'Rushworth'}}
# {'_id': {'Country': 'Australia', 'City': 'Mount Eliza'}}
# {'_id': {'Country': 'Australia', 'City': 'Mareeba'}}
# {'_id': {'Country': 'Australia', 'City': 'Elderslie'}}
# {'_id': {'Country': 'Australia', 'City': 'Knoxfield'}}
# {'_id': {'Country': 'Australia', 'City': 'Bulimba'}}
# {'_id': {'Country': 'Australia', 'City': 'Gawler'}}
# {'_id': {'Country': 'Australia', 'City': 'Merrylands'}}
# {'_id': {'Country': 'Australia', 'City': 'Rydalmere'}}
# {'_id': {'Country': 'Australia', 'City': 'Caloundra'}}
# {'_id': {'Country': 'Australia', 'City': 'Sale'}}
# {'_id': {'Country': 'Australia', 'City': 'Drouin'}}
# {'_id': {'Country': 'Australia', 'City': 'Preston'}}
# {'_id': {'Country': 'Australia', 'City': 'Bankstown'}}
# {'_id': {'Country': 'Australia', 'City': 'Langwarrin'}}
# {'_id': {'Country': 'Australia', 'City': 'Thornbury'}}
# {'_id': {'Country': 'Australia', 'City': 'Burleigh Heads'}}
# {'_id': {'Country': 'Australia', 'City': 'Clyde North'}}
# {'_id': {'Country': 'Australia', 'City': 'Ormond'}}
# {'_id': {'Country': 'Australia', 'City': 'Woodside'}}
# {'_id': {'Country': 'Australia', 'City': 'Moggill'}}
# {'_id': {'Country': 'Australia', 'City': 'Roleystone'}}
# {'_id': {'Country': 'Australia', 'City': 'Fyshwick'}}
# {'_id': {'Country': 'Australia', 'City': 'Emerald'}}
# {'_id': {'Country': 'Australia', 'City': 'Goodna'}}
# {'_id': {'Country': 'Australia', 'City': 'Ivanhoe'}}
# {'_id': {'Country': 'Australia', 'City': 'Bayswater'}}
# {'_id': {'Country': 'Australia', 'City': 'Morpeth'}}
# {'_id': {'Country': 'Australia', 'City': 'Heidelberg'}}
# {'_id': {'Country': 'Australia', 'City': 'Mount Waverley'}}
# {'_id': {'Country': 'Australia', 'City': 'Mulgrave'}}
# {'_id': {'Country': 'Australia', 'City': 'Atherton'}}
# {'_id': {'Country': 'Australia', 'City': 'Waterloo'}}
# {'_id': {'Country': 'Australia', 'City': 'Bendigo'}}
# {'_id': {'Country': 'Australia', 'City': 'Campbelltown'}}
# {'_id': {'Country': 'Australia', 'City': 'Ermington'}}
# {'_id': {'Country': 'Australia', 'City': 'Whale Beach'}}
# {'_id': {'Country': 'Australia', 'City': 'Nambour'}}
# {'_id': {'Country': 'Australia', 'City': 'Claremont'}}
# {'_id': {'Country': 'Australia', 'City': 'Burpengary'}}
# {'_id': {'Country': 'Australia', 'City': 'Hughesdale'}}
# {'_id': {'Country': 'Australia', 'City': 'Greenslopes'}}
# {'_id': {'Country': 'Australia', 'City': 'Mittagong'}}
# {'_id': {'Country': 'Australia', 'City': 'Balcatta'}}
# {'_id': {'Country': 'Australia', 'City': 'Woonona'}}
# {'_id': {'Country': 'Australia', 'City': 'Boyanup'}}
# {'_id': {'Country': 'Australia', 'City': 'Veresdale'}}
# {'_id': {'Country': 'Australia', 'City': 'Strathpine'}}
# {'_id': {'Country': 'Australia', 'City': 'Strathfieldsaye'}}
# {'_id': {'Country': 'Australia', 'City': 'West Wallsend'}}
# {'_id': {'Country': 'Australia', 'City': 'Homebush'}}
# {'_id': {'Country': 'Australia', 'City': 'Berowra'}}
# {'_id': {'Country': 'Australia', 'City': 'Wollongong'}}
# {'_id': {'Country': 'Australia', 'City': 'Byrneside'}}
# {'_id': {'Country': 'Australia', 'City': 'Glenfield'}}
# {'_id': {'Country': 'Australia', 'City': 'Penrith'}}
# {'_id': {'Country': 'Australia', 'City': 'Lidcombe'}}
# {'_id': {'Country': 'Australia', 'City': 'Newstead'}}
# {'_id': {'Country': 'Australia', 'City': 'Mooloolabah'}}
# {'_id': {'Country': 'Australia', 'City': 'Wallan'}}
# {'_id': {'Country': 'Australia', 'City': 'Ascot Vale'}}
# {'_id': {'Country': 'Australia', 'City': 'Novar Gardens'}}
# {'_id': {'Country': 'Australia', 'City': 'Craigieburn'}}
# {'_id': {'Country': 'Australia', 'City': 'Barwon Heads'}}
# {'_id': {'Country': 'Australia', 'City': 'Warrandyte'}}
# {'_id': {'Country': 'Australia', 'City': 'Wanniassa'}}
# {'_id': {'Country': 'Australia', 'City': 'Marong'}}
# {'_id': {'Country': 'Australia', 'City': 'Berkeley'}}
# {'_id': {'Country': 'Australia', 'City': 'Lane Cove'}}
# {'_id': {'Country': 'Australia', 'City': 'Alfredton'}}
# {'_id': {'Country': 'Australia', 'City': 'Aberglasslyn'}}
# {'_id': {'Country': 'Australia', 'City': 'Milperra'}}
# {'_id': {'Country': 'Australia', 'City': 'Carlton'}}
# {'_id': {'Country': 'Australia', 'City': 'Eumundi'}}
# {'_id': {'Country': 'Australia', 'City': 'Maroubra'}}
# {'_id': {'Country': 'Australia', 'City': 'Loftus'}}
# {'_id': {'Country': 'Australia', 'City': 'Aspley'}}
# {'_id': {'Country': 'Australia', 'City': 'Bondi Junction'}}
# {'_id': {'Country': 'Australia', 'City': 'Chirnside Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Annandale'}}
# {'_id': {'Country': 'Australia', 'City': 'Port Kennedy'}}
# {'_id': {'Country': 'Australia', 'City': 'Newington'}}
# {'_id': {'Country': 'Australia', 'City': 'Carlton North'}}
# {'_id': {'Country': 'Australia', 'City': 'Southport'}}
# {'_id': {'Country': 'Australia', 'City': 'Girraween'}}
# {'_id': {'Country': 'Australia', 'City': 'Yaroomba'}}
# {'_id': {'Country': 'Australia', 'City': 'Athelstone'}}
# {'_id': {'Country': 'Australia', 'City': 'Point Cook'}}
# {'_id': {'Country': 'Australia', 'City': 'Mosman'}}
# {'_id': {'Country': 'Australia', 'City': 'Weston Creek'}}
# {'_id': {'Country': 'Australia', 'City': 'St Kilda'}}
# {'_id': {'Country': 'Australia', 'City': 'Gaythorne'}}
# {'_id': {'Country': 'Australia', 'City': 'Port Augusta'}}
# {'_id': {'Country': 'Australia', 'City': 'Blayney'}}
# {'_id': {'Country': 'Australia', 'City': 'Brunswick East'}}
# {'_id': {'Country': 'Australia', 'City': 'Pimpama'}}
# {'_id': {'Country': 'Australia', 'City': 'Point Clare'}}
# {'_id': {'Country': 'Australia', 'City': 'Gracemere'}}
# {'_id': {'Country': 'Australia', 'City': 'Hervey Bay'}}
# {'_id': {'Country': 'Australia', 'City': 'Beaudesert'}}
# {'_id': {'Country': 'Australia', 'City': 'Woodville'}}
# {'_id': {'Country': 'Australia', 'City': 'Warrawee'}}
# {'_id': {'Country': 'Australia', 'City': 'Elsternwick'}}
# {'_id': {'Country': 'Australia', 'City': 'Gosnells'}}
# {'_id': {'Country': 'Australia', 'City': 'Cardigan'}}
# {'_id': {'Country': 'Australia', 'City': 'Leongatha'}}
# {'_id': {'Country': 'Australia', 'City': 'Medowie'}}
# {'_id': {'Country': 'Australia', 'City': 'Mount Druitt'}}
# {'_id': {'Country': 'Australia', 'City': 'Corinda'}}
# {'_id': {'Country': 'Australia', 'City': 'Glenelg'}}
# {'_id': {'Country': 'Australia', 'City': 'Narara'}}
# {'_id': {'Country': 'Australia', 'City': 'Woolloomooloo'}}
# {'_id': {'Country': 'Australia', 'City': 'Saint Marys'}}
# {'_id': {'Country': 'Australia', 'City': 'Prahran'}}
# {'_id': {'Country': 'Australia', 'City': 'Artarmon'}}
# {'_id': {'Country': 'Australia', 'City': 'Tallebudgera'}}
# {'_id': {'Country': 'Australia', 'City': 'Minto'}}
# {'_id': {'Country': 'Australia', 'City': 'Cremorne'}}
# {'_id': {'Country': 'Australia', 'City': 'Bundaberg'}}
# {'_id': {'Country': 'Australia', 'City': 'Bermagui'}}
# {'_id': {'Country': 'Australia', 'City': 'Mentone'}}
# {'_id': {'Country': 'Australia', 'City': 'Albury'}}
# {'_id': {'Country': 'Australia', 'City': 'Springwood'}}
# {'_id': {'Country': 'Australia', 'City': 'Hughenden'}}
# {'_id': {'Country': 'Australia', 'City': 'Kennington'}}
# {'_id': {'Country': 'Australia', 'City': 'Tarneit'}}
# {'_id': {'Country': 'Australia', 'City': 'Collaroy'}}
# {'_id': {'Country': 'Australia', 'City': 'Doncaster East'}}
# {'_id': {'Country': 'Australia', 'City': 'Waitara'}}
# {'_id': {'Country': 'Australia', 'City': 'Happy Valley'}}
# {'_id': {'Country': 'Australia', 'City': 'Welland'}}
# {'_id': {'Country': 'Australia', 'City': 'Kiama'}}
# {'_id': {'Country': 'Australia', 'City': 'Coniston'}}
# {'_id': {'Country': 'Australia', 'City': 'Rochedale'}}
# {'_id': {'Country': 'Australia', 'City': 'Cranbourne'}}
# {'_id': {'Country': 'Australia', 'City': 'Greenwich'}}
# {'_id': {'Country': 'Australia', 'City': 'Benowa'}}
# {'_id': {'Country': 'Australia', 'City': 'Yanchep'}}
# {'_id': {'Country': 'Australia', 'City': 'Sebastopol'}}
# {'_id': {'Country': 'Australia', 'City': 'Smithfield'}}
# {'_id': {'Country': 'Australia', 'City': 'Dulwich Hill'}}
# {'_id': {'Country': 'Australia', 'City': 'Kenthurst'}}
# {'_id': {'Country': 'Australia', 'City': 'Gordon'}}
# {'_id': {'Country': 'Australia', 'City': 'Albion'}}
# {'_id': {'Country': 'Australia', 'City': 'Goonellabah'}}
# {'_id': {'Country': 'Australia', 'City': 'Murrumbeena'}}
# {'_id': {'Country': 'Australia', 'City': 'Kirrawee'}}
# {'_id': {'Country': 'Australia', 'City': 'Gosford'}}
# {'_id': {'Country': 'Australia', 'City': 'Edmonton'}}
# {'_id': {'Country': 'Australia', 'City': 'Cheltenham'}}
# {'_id': {'Country': 'Australia', 'City': 'Morphett Vale'}}
# {'_id': {'Country': 'Australia', 'City': 'Magill'}}
# {'_id': {'Country': 'Australia', 'City': 'Hallett Cove'}}
# {'_id': {'Country': 'Australia', 'City': 'Portland'}}
# {'_id': {'Country': 'Australia', 'City': 'Blacktown'}}
# {'_id': {'Country': 'Australia', 'City': 'Beaumaris'}}
# {'_id': {'Country': 'Australia', 'City': 'Tanunda'}}
# {'_id': {'Country': 'Australia', 'City': 'Trigg'}}
# {'_id': {'Country': 'Australia', 'City': 'Tatura'}}
# {'_id': {'Country': 'Australia', 'City': 'Stirling'}}
# {'_id': {'Country': 'Australia', 'City': 'Robinvale'}}
# {'_id': {'Country': 'Australia', 'City': 'Keswick'}}
# {'_id': {'Country': 'Australia', 'City': 'Blaxland'}}
# {'_id': {'Country': 'Australia', 'City': 'Davistown'}}
# {'_id': {'Country': 'Australia', 'City': 'Maleny'}}
# {'_id': {'Country': 'Australia', 'City': 'Kawungan'}}
# {'_id': {'Country': 'Australia', 'City': 'Mackay'}}
# {'_id': {'Country': 'Australia', 'City': 'Armstrong Creek'}}
# {'_id': {'Country': 'Australia', 'City': 'Williamstown'}}
# {'_id': {'Country': 'Australia', 'City': 'Dapto'}}
# {'_id': {'Country': 'Australia', 'City': 'Shorncliffe'}}
# {'_id': {'Country': 'Australia', 'City': 'Clayton'}}
# {'_id': {'Country': 'Australia', 'City': 'Kellyville'}}
# {'_id': {'Country': 'Australia', 'City': 'Esperance'}}
# {'_id': {'Country': 'Australia', 'City': 'Elwood'}}
# {'_id': {'Country': 'Australia', 'City': 'Bronte'}}
# {'_id': {'Country': 'Australia', 'City': 'Kilcoy'}}
# {'_id': {'Country': 'Australia', 'City': 'Swanbourne'}}
# {'_id': {'Country': 'Australia', 'City': 'Ashfield'}}
# {'_id': {'Country': 'Australia', 'City': 'Beechboro'}}
# {'_id': {'Country': 'Australia', 'City': 'Pambula'}}
# {'_id': {'Country': 'Australia', 'City': 'Waurn Ponds'}}
# {'_id': {'Country': 'Australia', 'City': 'Fitzroy'}}
# {'_id': {'Country': 'Australia', 'City': 'Rowville'}}
# {'_id': {'Country': 'Australia', 'City': 'Millthorpe'}}
# {'_id': {'Country': 'Australia', 'City': 'Newcastle'}}
# {'_id': {'Country': 'Australia', 'City': 'Dee Why'}}
# {'_id': {'Country': 'Australia', 'City': 'Hampton Park'}}
# {'_id': {'Country': 'Australia', 'City': 'Fremantle'}}
# {'_id': {'Country': 'Australia', 'City': 'Springvale South'}}
# {'_id': {'Country': 'Australia', 'City': 'Illewong'}}
# ...
# {'_id': {'Country': 'United States', 'City': 'Raritan'}}
# {'_id': {'Country': 'United States', 'City': 'Zanesville'}}
# {'_id': {'Country': 'United States', 'City': 'Nottingham'}}
# {'_id': {'Country': 'United States', 'City': 'Hopewell'}}
# {'_id': {'Country': 'United States', 'City': 'Riverton'}}
# {'_id': {'Country': 'United States', 'City': 'Lathrop'}}
# {'_id': {'Country': 'United States', 'City': 'El Dorado Hills'}}
# {'_id': {'Country': 'United States', 'City': 'Foxborough'}}
# {'_id': {'Country': 'United States', 'City': 'Redwood City'}}
# {'_id': {'Country': 'United States', 'City': 'Saint Bonaventure'}}
# {'_id': {'Country': 'United States', 'City': 'Lake Elsinore'}}
# {'_id': {'Country': 'United States', 'City': 'Lordsburg'}}
# {'_id': {'Country': 'United States', 'City': 'Pennsville'}}
# {'_id': {'Country': 'United States', 'City': 'Leavenworth'}}
# {'_id': {'Country': 'United States', 'City': 'Port Huron'}}
# {'_id': {'Country': 'United States', 'City': 'North Richland Hills'}}
# {'_id': {'Country': 'United States', 'City': 'Daingerfield'}}
# {'_id': {'Country': 'United States', 'City': 'Garrison'}}
# {'_id': {'Country': 'United States', 'City': 'Foley'}}
# {'_id': {'Country': 'United States', 'City': 'Noel'}}
# {'_id': {'Country': 'United States', 'City': 'Vanceboro'}}
# {'_id': {'Country': 'United States', 'City': 'Sunapee'}}
# {'_id': {'Country': 'United States', 'City': 'Manor'}}
# {'_id': {'Country': 'United States', 'City': 'Travelers Rest'}}
# {'_id': {'Country': 'United States', 'City': 'Taylorsville'}}
# {'_id': {'Country': 'United States', 'City': 'Mount Sinai'}}
# {'_id': {'Country': 'United States', 'City': 'Española'}}
# {'_id': {'Country': 'United States', 'City': 'Bronxville'}}
# {'_id': {'Country': 'United States', 'City': 'Madisonville'}}
# {'_id': {'Country': 'United States', 'City': 'Lemont'}}
# {'_id': {'Country': 'United States', 'City': 'Ridgeland'}}
# {'_id': {'Country': 'United States', 'City': 'Huxley'}}
# {'_id': {'Country': 'United States', 'City': 'Sedalia'}}
# {'_id': {'Country': 'United States', 'City': 'Spokane'}}
# {'_id': {'Country': 'United States', 'City': 'Evergreen Park'}}
# {'_id': {'Country': 'United States', 'City': 'Gaston'}}
# {'_id': {'Country': 'United States', 'City': 'Hampton Bays'}}
# {'_id': {'Country': 'United States', 'City': 'Fort Riley North'}}
# {'_id': {'Country': 'United States', 'City': 'South Windsor'}}
# {'_id': {'Country': 'United States', 'City': 'Livingston'}}
# {'_id': {'Country': 'United States', 'City': 'Laguna Hills'}}
# {'_id': {'Country': 'United States', 'City': 'Pagosa Springs'}}
# {'_id': {'Country': 'United States', 'City': 'Evergreen'}}
# {'_id': {'Country': 'United States', 'City': 'Harvey'}}
# {'_id': {'Country': 'United States', 'City': 'West Falmouth'}}
# {'_id': {'Country': 'United States', 'City': 'Ambler'}}
# {'_id': {'Country': 'United States', 'City': 'Rougemont'}}
# {'_id': {'Country': 'United States', 'City': 'Redwood Valley'}}
# {'_id': {'Country': 'United States', 'City': 'Stevenson'}}
# {'_id': {'Country': 'United States', 'City': 'Jenkintown'}}
# {'_id': {'Country': 'United States', 'City': 'Fort Loramie'}}
# {'_id': {'Country': 'United States', 'City': 'Arp'}}
# {'_id': {'Country': 'United States', 'City': 'Aurora'}}
# {'_id': {'Country': 'United States', 'City': 'Pine Hills'}}
# {'_id': {'Country': 'United States', 'City': 'Swarthmore'}}
# {'_id': {'Country': 'United States', 'City': 'Wyandotte'}}
# {'_id': {'Country': 'United States', 'City': 'Poway'}}
# {'_id': {'Country': 'United States', 'City': 'Blythe'}}
# {'_id': {'Country': 'United States', 'City': 'Warminster'}}
# {'_id': {'Country': 'United States', 'City': 'Wanakena'}}
# {'_id': {'Country': 'United States', 'City': 'Hackettstown'}}
# {'_id': {'Country': 'United States', 'City': 'Athol'}}
# {'_id': {'Country': 'United States', 'City': 'Niantic'}}
# {'_id': {'Country': 'United States', 'City': 'DeLand'}}
# {'_id': {'Country': 'United States', 'City': 'Edwardsburg'}}
# {'_id': {'Country': 'United States', 'City': 'Cedarburg'}}
# {'_id': {'Country': 'United States', 'City': 'Union'}}
# {'_id': {'Country': 'United States', 'City': 'Madison'}}
# {'_id': {'Country': 'United States', 'City': 'Scarborough'}}
# {'_id': {'Country': 'United States', 'City': 'Greenbrae'}}
# {'_id': {'Country': 'United States', 'City': 'Prosper'}}
# {'_id': {'Country': 'United States', 'City': 'Long Lake'}}
# {'_id': {'Country': 'United States', 'City': 'Chino'}}
# {'_id': {'Country': 'United States', 'City': 'Fort Atkinson'}}
# {'_id': {'Country': 'United States', 'City': 'Salinas'}}
# {'_id': {'Country': 'United States', 'City': 'Marshalltown'}}
# {'_id': {'Country': 'United States', 'City': 'Holliston'}}
# {'_id': {'Country': 'United States', 'City': 'Lake Odessa'}}
# {'_id': {'Country': 'United States', 'City': 'Hudson'}}
# {'_id': {'Country': 'United States', 'City': 'Pinehurst'}}
# {'_id': {'Country': 'United States', 'City': 'Opelousas'}}
# {'_id': {'Country': 'United States', 'City': 'Hyannis'}}
# {'_id': {'Country': 'United States', 'City': 'Savoy'}}
# {'_id': {'Country': 'United States', 'City': 'Bethalto'}}
# {'_id': {'Country': 'United States', 'City': 'Boardman'}}
# {'_id': {'Country': 'United States', 'City': 'Fond du Lac'}}
# {'_id': {'Country': 'United States', 'City': 'Schertz'}}
# {'_id': {'Country': 'United States', 'City': 'Elk City'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Tacuarembó'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Minas'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Pocitos'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Las Piedras'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Arroyo de la Virgen'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Juan L. Lacaze'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Maldonado'}}
# {'_id': {'Country': 'Uruguay', 'City': 'San Carlos'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Solymar'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Arenal'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Fray Bentos'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Shangrila'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Florida'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Santa Lucia'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Totoral del Sauce'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Pando'}}
# {'_id': {'Country': 'Uruguay', 'City': 'San Jose de Mayo'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Colonia del Sacramento'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Vichadero'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Libertad'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Salto'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Baltasar Brum'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Canelones'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Punta del Este'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Paysandú'}}
# {'_id': {'Country': 'Uruguay', 'City': 'Montevideo'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Boysun'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Amir Timur'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Marhamat'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Jizzakh'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Nukus'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Urgench'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Margilan'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Tashkent'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Navoiy'}}
# {'_id': {'Country': 'Uzbekistan', 'City': 'Yangiovul'}}
# {'_id': {'Country': 'Vanuatu', 'City': 'Port Vila'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barbacoas'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Felipe'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Agua Salada'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Arenilla'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Arichuna'}}
# {'_id': {'Country': 'Venezuela', 'City': 'El Paramito'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barrio Ajuro'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Altamira'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Turmero'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Altagracia de Orituco'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Guatire'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Maracaibo'}}
# {'_id': {'Country': 'Venezuela', 'City': 'El Corozo'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Porlamar'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Alto de Los Godos'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Ciudad Ojeda'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Antonio de Los Altos'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Aguirre'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Bergantin'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Ciudad Bolívar'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barranquitas'}}
# {'_id': {'Country': 'Venezuela', 'City': 'La Guaira'}}
# {'_id': {'Country': 'Venezuela', 'City': 'El Tigre'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Maturín'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Aparicio'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Puerto Ordaz and San Felix'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Santa Teresa del Tuy'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Cristóbal'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Villa de Cura'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Altagracia'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barquisimeto'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Agua Fria'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Chimpire'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Mateo'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Tariba'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Cagua'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Mérida'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Charallave'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Guarenas'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barcelona'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Casanay'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Acarigua'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Belen'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Catia La Mar'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Caracas'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Valencia'}}
# {'_id': {'Country': 'Venezuela', 'City': 'La Victoria'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Juan de los Morros'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Punto Fijo'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Araguita'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Bachaquero'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Santa Cruz'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Machiques'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Puerto La Cruz'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Guayana'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Montalban'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Maracay'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Apartaderos'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Villa Bruzual'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Anaco'}}
# {'_id': {'Country': 'Venezuela', 'City': 'San Carlos'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Coro'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Ocumare'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Agua Linda'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Trujillo'}}
# {'_id': {'Country': 'Venezuela', 'City': 'Barinas'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Tan Binh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ban Pac Ly'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Mai Dong'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hung Ha'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Hoa Binh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Dong Nai'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Vinh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Bac Giang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Duy Xuyen'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Huế'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Tay Ninh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ho Chi Minh City'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Binh Phuoc'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Tuyen Quang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Buon Ma Thuot'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Yen Phong'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quan Tan Phu'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Hóa'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Can Duoc'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thu Dau Mot'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Ninh Binh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Da Lat'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Cam Le'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Thai Binh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Lang Son'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Nha Be'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quang Nam'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Can Tho'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Vĩnh Long'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Sop Khine'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Dong Ha'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ba Ria'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Sin Chai'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Rach Gia'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Dien Chau'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Qui Nhon'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Da Nang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Go Vap'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thu Duc'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Xuan'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Phung Hiep'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Chau Thanh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Phu Ly'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hanoi'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hoi An'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quan Phu Nhuan'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hoa Vang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Nha Trang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Thai Nguyen'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Cua Lo'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Tien Giang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Di An'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thuan An'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ca Mau'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hoan Kiem'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hong Bang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quang Ninh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Bac Ninh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Yen Bai'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Vũng Tàu'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Cho Gao'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hung Yen'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Tam Ky'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quảng Ngãi'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Tra Vinh'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Hai Duong'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Bien Hoa'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Soc Trang'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Haiphong'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Thanh Pho Uong Bi'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ha Dong'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Phan Thiết'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Quan Hoa'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Hoang Mai'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Bến Tre'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Dong Hoi'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Cau Giay'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Nam Định'}}
# {'_id': {'Country': 'Vietnam', 'City': 'My Hao'}}
# {'_id': {'Country': 'Vietnam', 'City': 'Ha Tinh'}}
# {'_id': {'Country': 'Yemen', 'City': 'Mocha'}}
# {'_id': {'Country': 'Yemen', 'City': 'Ta`izz'}}
# {'_id': {'Country': 'Yemen', 'City': 'Sanaa'}}
# {'_id': {'Country': 'Yemen', 'City': 'Aden'}}
# {'_id': {'Country': 'Yemen', 'City': 'Mukalla'}}
# {'_id': {'Country': 'Yemen', 'City': 'Dhamar'}}
# {'_id': {'Country': 'Zambia', 'City': 'Livingstone'}}
# {'_id': {'Country': 'Zambia', 'City': 'Lusaka'}}
# {'_id': {'Country': 'Zambia', 'City': 'Kitwe'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Bulawayo'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Harare'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Chinhoyi'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Gwanda'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Chitungwiza'}}
# {'_id': {'Country': 'Zimbabwe', 'City': 'Mutare'}}
# {'_id': {'Country': 'Åland', 'City': 'Mariehamn'}}

# %% [markdown]
# ---
# Unique `OS`

# %%
db.clicks.find().distinct('device.OS')
# Out:
# ['Android',
#  'BlackBerry OS',
#  'Chrome OS',
#  'Chromecast',
#  'Fedora',
#  'FreeBSD',
#  'Kindle',
#  'Linux',
#  'Mac OS X',
#  'NetBSD',
#  'OpenBSD',
#  'Other',
#  'Solaris',
#  'Tizen',
#  'Ubuntu',
#  'Windows',
#  'Windows Phone',
#  'iOS']

# %%
len(db.clicks.find().distinct('device.OS'))
# Out:
# 18

# %% [markdown]
# ---
# Unique `Browser`

# %%
db.clicks.find().distinct('device.Browser')
# Out:
# ['AdsBot-Google',
#  'AhrefsBot',
#  'Amazon Silk',
#  'Android',
#  'AppEngine-Google',
#  'Apple Mail',
#  'BingPreview',
#  'BlackBerry WebKit',
#  'Chrome',
#  'Chrome Mobile',
#  'Chrome Mobile WebView',
#  'Chrome Mobile iOS',
#  'Chromium',
#  'Coc Coc',
#  'Coveobot',
#  'Crosswalk',
#  'Dragon',
#  'DuckDuckBot',
#  'Edge',
#  'Edge Mobile',
#  'Electron',
#  'Epiphany',
#  'Facebook',
#  'FacebookBot',
#  'Firefox',
#  'Firefox Mobile',
#  'Firefox iOS',
#  'HbbTV',
#  'HeadlessChrome',
#  'HubSpot Crawler',
#  'IE',
#  'IE Mobile',
#  'Iceweasel',
#  'Iron',
#  'JobBot',
#  'Jooblebot',
#  'K-Meleon',
#  'Kindle',
#  'Konqueror',
#  'Magus Bot',
#  'Mail.ru Chromium Browser',
#  'Maxthon',
#  'Mobile Safari',
#  'Mobile Safari UI/WKWebView',
#  'MobileIron',
#  'NetFront',
#  'Netscape',
#  'Opera',
#  'Opera Coast',
#  'Opera Mini',
#  'Opera Mobile',
#  'Other',
#  'PagePeeker',
#  'Pale Moon',
#  'PetalBot',
#  'PhantomJS',
#  'Pinterest',
#  'Puffin',
#  'Python Requests',
#  'QQ Browser',
#  'QQ Browser Mobile',
#  'Radius Compliance Bot',
#  'Safari',
#  'Samsung Internet',
#  'SeaMonkey',
#  'Seekport Crawler',
#  'SiteScoreBot',
#  'Sleipnir',
#  'Sogou Explorer',
#  'Thunderbird',
#  'UC Browser',
#  'Vivaldi',
#  'WebKit Nightly',
#  'WordPress',
#  'Yandex Browser',
#  'YandexAccessibilityBot',
#  'YandexBot',
#  'YandexSearch',
#  'Yeti',
#  'YisouSpider',
#  'moatbot',
#  'net/bot']

# %%
len(db.clicks.find().distinct('device.Browser'))
# Out:
# 82

# %% [markdown]
# ---
# Unique `Activity`

# %%
db.clicks.find().distinct('Activity')
# Out:
# ['click', 'pageload']

# %% [markdown]
# ----
# Number of unique prodcuts

# %%
len(db.clicks.find().distinct('ProductID'))
# Out:
# 10938

# %% [markdown]
# ---
# # Queries
#
# ----

# %% [markdown]
# ----
# ### Q1
# Get the percentage of documents where there are user ids present. Also get the percentage of documents where the user ids are absent.
#
# ***Hint - Keep total documents count in a separate variable beforehand.***

# %%
# Find total documents in the collection
total_docs_count = collection.count_documents({})
print(f"Total documents in the collection: {total_docs_count}")

# %%
cur = db.clicks.aggregate([
                
            # Stage 1 - check if user.UserID is present
            {
                # fill the operator to use
                '$match': {'user.UserID': {'$exists': True}}
            },

            # Stage 2- count the filtered documents
            {
                # fill in the stage operator to use
                '$group': {'_id': None, 'signed_up': {'$sum': 1}}
            },

            # Stage 3 - find the percentage
            {
                '$project': {
                    '_id': 0,
                    'Percentage_signed_up': {'$multiply':[
                                                            {'$divide': ['$signed_up', total_docs_count]}, 
                                                            100
                                                        ]
                                            },
                    'Percentage_not_signed_up': {'$multiply':[
                                                                # fill the value
                                                                {'$divide': [
                                                                                # users who haven't signed up
                                                                                {'$subtract': [total_docs_count, '$signed_up']}, 
                                                                                total_docs_count
                                                                            ]
                                                                },
                                                                100
                                                            ]
                                                }
                }
            }
        ],
        allowDiskUse=True)

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ----
# ### Q2
# What was the most popular product?

# %%
cur = db.clicks.aggregate([
    
            # Stage 1 - group on the ProductID field
            {
                # fill in the stage operator to use
                '$group': {
                                '_id': '$ProductID',
                                'Count': {'$sum': 1}
                            }
            },
    
            # Stage 2 - sort the groups based on the Count
            {
                '$sort': {'Count': -1}# Enter your code here
            },
    
            # Stage 3 - limit the result to return the product with the highest count
            {
                '$limit': 1# Enter your code here
            }
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ----
# ### Q3
# Count the number of `click` and number of `pageload` for each signed up user. Sort the result in ascending order of the `user.UserID`.

# %%
cur = db.clicks.aggregate([
            # Stage 1 - Filter only signed-up users (users with UserID)
    {
        '$match': {'user.UserID': {'$exists': True}}
    },

    # Stage 2 - Group by user.UserID and count clicks and pageloads
    {
        '$group': {
            '_id': '$user.UserID',
            'clicks': {'$sum': {'$cond': [{'$eq': ['$Activity', 'click']}, 1, 0]}},
            'pageloads': {'$sum': {'$cond': [{'$eq': ['$Activity', 'pageload']}, 1, 0]}}
        }
    },

    # Stage 3 - Sort by UserID in ascending order
    {
        '$sort': {'_id': 1}
    }# Enter your code here
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ---
# ### Q4
# Count the number of records per `Country`. Sort the result in descending order of number of records.

# %%
cur = db.clicks.aggregate([
            # Stage 1 - Filter only signed-up users (users with UserID)
    {
        '$match': {'user.UserID': {'$exists': True}}
    },

    # Stage 2 - Group by user.UserID and count clicks and pageloads
    {
        '$group': {
            '_id': '$user.UserID',
            'clicks': {'$sum': {'$cond': [{'$eq': ['$Activity', 'click']}, 1, 0]}},
            'pageloads': {'$sum': {'$cond': [{'$eq': ['$Activity', 'pageload']}, 1, 0]}}
        }
    },

    # Stage 3 - Sort by UserID in ascending order
    {
        '$sort': {'_id': 1}
    }# Enter your code here
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ----
# ### Q5
# What is the most common/frequently used `OS`?
#
# And, what is the most common/frequently used `Browser`?
#
# Also get the count for both.

# %%
cur = db.clicks.aggregate([
    
            # Stage - Sub-pipeline for each result
            {
                # Fill in the stage operator
                 # Stage 1 - Group by OS and count occurrences
    {
        '$group': {
            '_id': '$device.OS',
            'OS_Count': {'$sum': 1}
        }
    },

    # Stage 2 - Sort OS by usage count in descending order
    {
        '$sort': {'OS_Count': -1}
    },

    # Stage 3 - Limit to the most used OS
    {
        '$limit': 1
    }
                    
                                'Most_used_OS': [
                                                    next(cur, {}).get('_id', 'Unknown')# Enter your code here
                                                ],
 {
        '$group': {
            '_id': '$device.Browser',  # Group by Browser
            'count': {'$sum': 1}  # Count occurrences
        }
    },
    {
        '$sort': {'count': -1}  # Sort in descending order
    },
    {
        '$limit': 1  # Get the most used Browser
    }
])
                                'Most_used_Browser': [
                                                        next(cur, {'_id': 'Unknown', 'count': 0})# Enter your code here
                                                    ]
                            }
            }
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ---
# ### Q6
# What is most common `OS` and `Browser` combination used by the users? Also get the count for it.
#
# `Example - {'Linux', 'Firefox'}`

# %%
cur = db.clicks.aggregate([
    # Stage 1 - Group by OS and count occurrences
    {
        '$group': {
            '_id': '$device.OS',
            'count': {'$sum': 1}
        }
    },

    # Stage 2 - Sort OS by usage count in descending order
    {
        '$sort': {'count': -1}
    },

    # Stage 3 - Limit to the most used OS
    {
        '$limit': 1
    }
])

# Print most used OS
for doc in cur:
    pp.pprint(doc)


cur = db.clicks.aggregate([
    
    # Stage 1 - Group by Browser and count occurrences
    {
        '$group': {
            '_id': '$device.Browser',
            'count': {'$sum': 1}
        }
    },

    # Stage 2 - Sort Browser by usage count in descending order
    {
        '$sort': {'count': -1}
    },

    # Stage 3 - Limit to the most used Browser
    {
        '$limit': 1
    }
])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ----
# ### Q7
# How many unique users were active in each week from  07/05/2018 - 27/05/2018?
#
# That is, how may unique users visited in the week from 07/05/2018 - 14/05/2018, from 15/05/2018 - 21/05/2018, and so on.
#
# ***Hint - You will need the `$addToSet` operator of `$bucket` stage operator and you will need to use the `$size` aggregation operator.***

# %%
cur = db.clicks.aggregate([
    
            # Stage 1 - filter documents for signed up users
            {
                '$match': {'user.UserID': {'$exists': True}}# Enter your code here
            },
    
            # Stage 2 - bucket by each week from 07/05/2018 - 27/05/2018
            {
                '$bucket': {
                                # fill in the value
                                'groupBy': '$VisitDateTime',
                    
                                'boundaries':  [
                ISODate("2018-05-07T00:00:00Z"),
                ISODate("2018-05-14T00:00:00Z"),
                ISODate("2018-05-21T00:00:00Z"),
                ISODate("2018-05-28T00:00:00Z")
            ],# create the bucket for each week 
                                            ,
                                # use $addToSet group accumulator operator
                                # to get an array of unique users for each week
                                'output': {
                                                 'Users': {'$addToSet': '$user.UserID'}# Enter your code here
                                        }
                            }
            },
                
            # Stage 3 - project the buckets
            {
                # fill in the stage operator
                '$project': {
                                '_id': 1,
                    
                                # use $size operator to count the number of users in the array created using $addToSet operator
                                'Unique_users': {'$size': '$Users'} # Enter your code here
                            }
            }
        ],
        allowDiskUse=True)

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ----
# ### Q8
# From all the unique users who visited between 07/05/2018 - 15/05/2018 dates, who visited the most number of times? Also get a list of unique products viewed by that user in the same duration.
#
# ***Hint - Use the `$addToSet` group accumulator operator.***

# %%
cur = db.clicks.aggregate([
            
            # Stage 1 - filter the documents between the dates and where the user id exists
            {
                '$match': { 
                                {
            'user.UserID': {'$exists': True},  
            'VisitDateTime': {
                '$gte': ISODate("2018-05-07T00:00:00Z"),  
                '$lte': ISODate("2018-05-27T23:59:59Z")
            }# Enter your code here
                            }
            },
    
            # Stage 2 - group the documents on the user id,
            #           count how many times that user visited the website,
            #           get an array of unique products viewed by user
            {
                '$group': {
                            '_id': '$user.UserID',
                            'Count': {'$sum': 1},
                    
                            # get an array of unique products viewed by the user
                            'Products': {'$addToSet': '$ProductID'}# Enter your code here
                        }
            },
            
            # Stage 3 - sort the group by the count of visits
            {
                '$sort': {'Count': -1}# Enter your code here
            },
            
            # Stage 4 - return the user who visited the most
            {
                '$limit': 1# Enter your code here
            }
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ---
# ### Q9
# Get the number of times each unique product was viewed by the user from the previous question in the same time duration.

# %%
cur = db.clicks.aggregate([
            {
                '$match': { 
                                # specify the date range
                                'VisitDateTime': {
                                                    '$gte': ISODate("2018-05-07T00:00:00Z"),  
                                                    '$lte': ISODate("2018-05-27T23:59:59Z")# Enter your code here
                                                },
                                
                                # fill in with the user id from previous query
                                'user.UserID': 'User123'
                            }
            },
            {
                '$group': {
                            '_id': '$ProductID',
                            'Count': {'$sum': 1}
                        }
            }
        ])

for doc in cur:
    pp.pprint(doc)

# %% [markdown]
# ------
# ### Q10
# What is the last viewed product by each signed up user till 27/05/2018?
#
# ***Hint - Use the `$last` group accumulator operator.***

# %%
cur = db.clicks.aggregate([
            
            # Stage 1 - filter documents where the user id exists
            {
                '$match': {
                    'user.UserID': {'$exists': True}# Enter your code here
            },
            
            # Stage 2 - sort documents by user id and date of visit
            {
                '$sort':  {
                    'user.UserID': 1,  # Sort by user ID in ascending order
                    'VisitDateTime': 1  # Sort by VisitDateTime in ascending order
                  }# Enter your code here
            },
    
            # Stage 3 - group on the user id and find the last product viewed
            {
                '$group': {
                            # fill the following
                            '_id': '$user.UserID',
                            
                            # get the last viewed product
                            'Last_product_viewed': {'$last': '$ProductID'}# Enter your code here
                        }
            }
        ],
        allowDiskUse=True)

for doc in cur:
    pp.pprint(doc)
